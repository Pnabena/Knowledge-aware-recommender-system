# %%
pip install tqdm
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.7 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pyspark

# %%
# import tarfile

# tar_path = "/Users/preye/Downloads/Masters AI:ML/Masters Project/Yelp JSON/yelp_dataset.tar"
# extract_to = "extracted_files"

# with tarfile.open(tar_path, "r") as tar:
#     tar.extractall(path=extract_to)

# print("Extraction complete")

# %%
# import tarfile
# from tqdm import tqdm
# from pathlib import Path

# tar_path = "/Users/preye/Downloads/Masters AI:ML/Masters Project/Yelp Photos/yelp_photos.tar"
# extract_to = "Image_files"

# Path(extract_to).mkdir(parents=True, exist_ok=True)

# with tarfile.open(tar_path, "r:*") as tar:
#     members = tar.getmembers()

#     for member in tqdm(members, desc="Extracting files", unit="file"):
#         tar.extract(member, path=extract_to)

# print("Extraction complete")
